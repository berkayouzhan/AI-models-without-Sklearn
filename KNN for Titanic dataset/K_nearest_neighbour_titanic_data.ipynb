# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # **Preprocessing**
# **This defines a function to preprocess the data.**

# %%
# Load and preprocess data
def preprocess_data(data):
    # Feature engineering

    #This extracts the title (Mr., Mrs., etc.) from the 'Name' column using a regular expression.
    data['Title'] = data['Name'].str.extract(' ([A-Za-z]+)\.', expand=False)

    #These lines create new features: 'FamilySize' (number of family members + 1) and 'IsAlone'
    data['FamilySize'] = data['SibSp'] + data['Parch'] + 1
    data['IsAlone'] = (data['FamilySize'] == 1).astype(int)

    # Encoding categorical variables
    data['Sex'] = data['Sex'].map({'female': 0, 'male': 1})
    data['Embarked'] = data['Embarked'].map({'S': 0, 'C': 1, 'Q': 2})

    #This selects the features we'll use and creates numpy arrays X (features) and y (target).
    features = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked', 'FamilySize', 'IsAlone']

    X = data[features].values
    y = data['Survived'].values

    # This loop imputes missing values in each column with the mean of that column.
    for col in range(X.shape[1]):
        mask = np.isnan(X[:, col])
        X[mask, col] = np.mean(X[~mask, col])

    return X, y

# %%
dataset = pd.read_csv('/content/titanic.csv')
X, y = preprocess_data(dataset)

# %%
dataset.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name  Sex   Age  SibSp  Parch  \
# 0                            Braund, Mr. Owen Harris    1  22.0      1      0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1      0
# 2                             Heikkinen, Miss. Laina    0  26.0      0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1      0
# 4                           Allen, Mr. William Henry    1  35.0      0      0
#
#              Ticket     Fare Cabin  Embarked Title  FamilySize  IsAlone
# 0         A/5 21171   7.2500   NaN       0.0    Mr           2        0
# 1          PC 17599  71.2833   C85       1.0   Mrs           2        0
# 2  STON/O2. 3101282   7.9250   NaN       0.0  Miss           1        1
# 3            113803  53.1000  C123       0.0   Mrs           2        0
# 4            373450   8.0500   NaN       0.0    Mr           1        1

# %%
# Normalize features
X_mean = np.mean(X, axis=0)
X_std = np.std(X, axis=0)
X = (X - X_mean) / X_std

# %% [markdown]
# # split data

# %%
# Split data
np.random.seed(42)
indices = np.random.permutation(len(X))
split = int(0.8 * len(X))
X_train, X_test = X[indices[:split]], X[indices[split:]]
y_train, y_test = y[indices[:split]], y[indices[split:]]

# %%
def manhattan_distance(X1, X2):
    return np.sum(np.abs(X1 - X2), axis=1)
def get_neighbors(X_train, y_train, test_row, k):
    distances = manhattan_distance(X_train, test_row)
    indices = np.argsort(distances)[:k]
    return y_train[indices]
def predict_classification(X_train, y_train, test_row, k):
    neighbors = get_neighbors(X_train, y_train, test_row, k)
    return np.bincount(neighbors).argmax()

def knn_predict(X_train, y_train, X_test, k):
    return np.array([predict_classification(X_train, y_train, row, k) for row in X_test])
#This function performs k-fold cross-validation.
def cross_val_score_manual(X, y, k, cv=10):
    fold_size = len(X) // cv
    scores = []
    for i in range(cv):
        start = i * fold_size
        end = (i + 1) * fold_size
        X_val, y_val = X[start:end], y[start:end]
        X_train = np.concatenate([X[:start], X[end:]], axis=0)
        y_train = np.concatenate([y[:start], y[end:]], axis=0)
        y_pred = knn_predict(X_train, y_train, X_val, k)
        scores.append(np.mean(y_pred == y_val))
    return np.mean(scores)

# %%
k_values = range(1, 31)  # Expanded range to check more k values
cv_scores = [cross_val_score_manual(X_train, y_train, k) for k in k_values]
optimal_k = k_values[np.argmax(cv_scores)]
print(f"Optimal k: {optimal_k}")

# Plot CV scores
plt.figure(figsize=(12, 6))
plt.plot(k_values, cv_scores, marker='o', linestyle='-', color='b')
plt.title('Cross-Validation Accuracy vs. k Value (Manhattan Distance)')
plt.xlabel('k')
plt.ylabel('Accuracy')
plt.xticks(k_values[::2])  # Show every other k value for readability
plt.grid(True)
plt.show()

# Final evaluation
y_pred_test = knn_predict(X_train, y_train, X_test, optimal_k)
accuracy_test = np.mean(y_pred_test == y_test)
print(f"Test set accuracy with optimal k ({optimal_k}): {accuracy_test}")

# Confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred_test)
print("Confusion Matrix:")
print(cm)

# Classification report
from sklearn.metrics import classification_report
print("\nClassification Report:")
print(classification_report(y_test, y_pred_test))
# Out:
# Optimal k: 13
# Test set accuracy with optimal k (13): 0.8100558659217877
# Confusion Matrix:
# [[100  14]
#  [ 20  45]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.88      0.85       114
#            1       0.76      0.69      0.73        65
#
#     accuracy                           0.81       179
#    macro avg       0.80      0.78      0.79       179
# weighted avg       0.81      0.81      0.81       179
